# %%
# !pip install SpeechRecognition
# Out:
# ...
#   Using cached speechrecognition-3.14.4-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# ...
#   Using cached audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# ...
#   Using cached standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Using cached speechrecognition-3.14.4-py3-none-any.whl (32.9 MB)
# Using cached audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Using cached standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Using cached standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# ...
#
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ------------------------------ --------- 3/4 [SpeechRecognition]
# ...

# %%
# !pip install pywhatkit
# Out:
# ...
#   Using cached pywhatkit-5.4-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached pyautogui-0.9.54-py3-none-any.whl
# ...
#   Using cached wikipedia-1.4.0-py3-none-any.whl
# ...
#   Using cached pymsgbox-2.0.1-py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached pytweening-1.2.0-py3-none-any.whl
# ...
#   Using cached pyscreeze-1.0.1-py3-none-any.whl
# ...
#   Using cached PyGetWindow-0.0.9-py3-none-any.whl
# ...
#   Using cached MouseInfo-0.1.3-py3-none-any.whl
# ...
#   Using cached PyRect-0.2.0-py2.py3-none-any.whl
# ...
#   Using cached pyperclip-1.11.0-py3-none-any.whl.metadata (2.4 kB)
# ...
# Using cached pywhatkit-5.4-py3-none-any.whl (15 kB)
# Using cached pymsgbox-2.0.1-py3-none-any.whl (10.0 kB)
# Using cached pyperclip-1.11.0-py3-none-any.whl (11 kB)
# ...
#
#    -------- -------------------------------  2/10 [pyrect]
#    ---------------- -----------------------  4/10 [pymsgbox]
#    -------------------- -------------------  5/10 [pygetwindow]
#    ---------------------------- -----------  7/10 [wikipedia]
# ...

# %%
# !pip install pyttsx3
# Out:
# ...
#   Using cached pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached comtypes-1.4.13-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# ...
# Using cached pyttsx3-2.99-py3-none-any.whl (32 kB)
# Using cached comtypes-1.4.13-py3-none-any.whl (254 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# ...
#
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
# ...

# %%
# !pip install matplotlib

# %%
# !pip install PyAudio
# Out:
# ...
#   Using cached PyAudio-0.2.14-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Using cached PyAudio-0.2.14-cp313-cp313-win_amd64.whl (173 kB)
# ...

# %%
import pyttsx3
import pywhatkit
speaker =pyttsx3.init()
speaker.say("Welcome Mahesh ")
speaker.runAndWait()

# %%
pywhatkit.sendwhatmsg_instantly("Enter your Whatsapp Number","Hii Mahesh sending from Python")

# %%
pywhatkit.sendwhatmsg("+91**********","Hello Mahesh sending from Python",10,50)
# Out:
# In 77726 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
